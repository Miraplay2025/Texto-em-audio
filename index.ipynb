# %%
# @title 🚀 Instalação Automática e Inicialização
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git
# %cd Texto-em-audio
# !pip install -r requirements.txt
# !python main.py
