# %%
# @title 🚀 MIRAPLAY AI - Ultra Realismo (High Fidelity)
# 1. Limpeza total para evitar conflitos de versão
# %cd /content/
# !rm -rf Texto-em-audio
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git
# %cd Texto-em-audio

# 2. Instalação de pacotes críticos de áudio do sistema
print("📦 Configurando drivers de áudio de alta fidelidade...")
# !apt-get update && apt-get install -y libsndfile1 ffmpeg build-essential

# 3. Instalação das bibliotecas de IA com foco em qualidade
print("⏳ Instalando Motores de Elite... Isso leva cerca de 2-3 minutos.")
# Forçamos a instalação correta do torch e coqui para evitar áudio robótico
# !pip install --upgrade pip
# !pip install -r requirements.txt

# 4. Verificação de GPU T4
import torch
if not torch.cuda.is_available():
    print("⚠️ ATENÇÃO: GPU não detectada! Vá em Ambiente de Execução > Alterar tipo e selecione T4 GPU.")
else:
    print(f"✅ GPU {torch.cuda.get_device_name(0)} detectada e pronta!")

# 5. Inicia o servidor com o novo motor Ultra-Realista
print("🎯 Iniciando Miraplay AI PRO...")
# !python main.py
