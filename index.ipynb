# %%
# @title 🚀 Instalação Otimizada Miraplay (XTTS v2 + T4)
# 1. Limpeza e download do projeto
# %cd /content/
# !rm -rf Texto-em-audio
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git
# %cd Texto-em-audio

# 2. Instala dependências de áudio do sistema (MUDANÇA ESSENCIAL)
# !apt-get update && apt-get install -y libsndfile1 ffmpeg

# 3. Instala as bibliotecas do Python
# !pip install --upgrade pip
# !pip install -r requirements.txt

# 4. Inicia o servidor de IA
# !python main.py
