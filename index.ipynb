# %%
# @title 🚀 Instalação Corrigida (Python 3.12 + XTTS v2)
# 1. Limpeza e download do projeto
# %cd /content/
# !rm -rf Texto-em-audio
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git
# %cd Texto-em-audio

# 2. Dependências do sistema e ferramentas de compilação
print("📦 Instalando dependências de sistema...")
# !apt-get update && apt-get install -y libsndfile1 ffmpeg build-essential python3-dev

# 3. Preparação do ambiente Python
print("🐍 Preparando instalador...")
# !pip install --upgrade pip setuptools wheel

# 4. Instalação das bibliotecas do projeto
print("⏳ Instalando bibliotecas de IA... Isso pode levar alguns minutos.")
# !pip install -r requirements.txt

# 5. Inicia o servidor de IA
print("🎯 Iniciando Miraplay AI...")
# !python main.py
