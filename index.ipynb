# %%
# @title 🚀 MIRAPLAY QWEN - High Fidelity
# 1. Configuração de diretório no Kaggle
import os
# %cd /kaggle/working/
# !rm -rf Texto-em-audio

# 2. Clonar repositório
print("📥 Clonando projeto...")
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git
# %cd Texto-em-audio

# 3. Instalar dependências de sistema e Python
print("📦 Instalando bibliotecas (Aguarde cerca de 3 min)...")
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install --upgrade pip
# !pip install -r requirements.txt

# 4. Iniciar sistema com GPU T4 x2
print("🎯 Iniciando Inteligência Pura Qwen...")
# !python main.py
