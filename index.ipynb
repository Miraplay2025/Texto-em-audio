# %%
# @title 🚀 Instalação Automática e Inicialização (Limpando Versão Anterior)
# 1. Volta para a pasta raiz e remove a pasta antiga para evitar erros
# %cd /content/
# !rm -rf Texto-em-audio

# 2. Baixa a versão atualizada do seu GitHub
# !git clone https://github.com/Miraplay2025/Texto-em-audio.git

# 3. Entra na pasta do projeto
# %cd Texto-em-audio

# 4. Instala as bibliotecas necessárias
# !pip install -r requirements.txt

# 5. Inicia o servidor de IA
# !python main.py
